# %%
import seaborn as sns
import pandas as pd

# %%
# 读取数据
data1 = pd.read_excel("C:/Users/20851/Desktop/2022年MathorCup大数据竞赛-赛道B初赛/附件1语音业务用户满意度数据.xlsx")

print(list(data1.columns))
# Out:
# ['用户id', '语音通话整体满意度', '网络覆盖与信号强度', '语音通话清晰度', '语音通话稳定性', '是否遇到过网络问题', '居民小区', '办公室', '高校', '商业街', '地铁', '农村', '高铁', '其他，请注明', '用户描述', '手机没有信号', '有信号无法拨通', '通话过程中突然中断', '通话中有杂音、听不清、断断续续', '串线', '通话过程中一方听不见', '其他，请注明.1', '用户描述.1', '脱网次数', 'mos质差次数', '未接通掉话次数', '重定向次数', '重定向驻留时长', '家宽投诉', '资费投诉', '4\\5G用户', '语音方式', '是否关怀用户', '是否去过营业厅', 'ARPU（家庭宽带）', '套外流量（MB）', '是否4G网络客户（本地剔除物联网）', '套外流量费（元）', '外省语音占比', '语音通话-时长（分钟）', '省际漫游-时长（分钟）', '终端品牌', '终端品牌类型', '当月ARPU', '当月MOU', '前3月ARPU', '前3月MOU', '外省流量占比', 'GPRS总流量（KB）', 'GPRS-国内漫游-流量（KB）', '是否5G网络客户', '是否实名登记用户', '客户星级标识', '当月欠费金额', '前第3个月欠费金额']

# %%
#数据清洗
#删除5列无用数据
del data1['用户id']
del data1['用户描述']
del data1['用户描述.1']
del data1['终端品牌']
del data1['终端品牌类型']

#对数据进行统一编码，前3列不用动
data1.iloc[:,4] = data1.iloc[:,4].map({1:1,2:0})
for i in range(5,20):
    data1.iloc[:,i] = data1.iloc[:,i].map({-1:0,1:1,2:1,3:1,4:1,5:1,6:1,7:1,98:1})

data1.iloc[:,23] = data1.iloc[:,23].fillna(0)
data1.iloc[:,24] = data1.iloc[:,24].fillna(0)
data1.iloc[:,27] = data1.iloc[:,27].map({'2G':2,'4G':4,'5G':5})
data1.iloc[:,28] = data1.iloc[:,28].map({'CSFB':0, 'EPSFB':1, 'GSM':2,'VOLTE':3,'VONR':4})
for i in ['是否关怀用户', '是否去过营业厅','是否4G网络客户（本地剔除物联网）', '是否5G网络客户', '是否实名登记用户']:
    data1[i] = data1[i].fillna(0).map({0:0,'是':1,'否':0})#29,30,33,45,46
data1.iloc[:,42] = data1.iloc[:,42].fillna(0)
data1.iloc[:,47] = data1.iloc[:,47].fillna(0).map({'未评级':0,'准星':0, '一星':1,'二星':2,'三星':3, '白金卡':4, '钻石卡':5, '银卡':6,'金卡':7})

data1 = data1.dropna()#删除后面的缺失行
print(data1.head(5))

#保存成excel文件
data1.to_excel("C:/Users/20851/Desktop/2022年MathorCup大数据竞赛-赛道B初赛/清洗后语音满意度数据.xlsx",index=None)
# Out:
#    语音通话整体满意度  网络覆盖与信号强度  语音通话清晰度  语音通话稳定性  是否遇到过网络问题  居民小区  办公室  高校  商业街  地铁  \
# 0         10          6        6        6          1     0    1   0    0   0
# 1          2          1        1        1          1     1    1   0    1   0
# 2         10          7        7        7          1     0    0   0    0   0
# 3          6          7        7        6          1     1    1   0    0   0
# 4          5          5        4        3          1     0    1   0    0   1
#
#    ...  前3月ARPU  前3月MOU  外省流量占比  GPRS总流量（KB）  GPRS-国内漫游-流量（KB）  是否5G网络客户  \
# 0  ...      0.0     480     1.0      8450801           8450801         1
# 1  ...      0.0     480     1.0     17425910          17425910         1
# 2  ...      0.0     413     1.0      6215849           6215849         0
# 3  ...      0.0     301     1.0      5370710           5370710         1
# 4  ...      0.0    1193     1.0      3857521           3857521         0
#
#    是否实名登记用户  客户星级标识  当月欠费金额  前第3个月欠费金额
# 0         0     6.0     0.0       0.00
# 1         1     6.0     0.0       0.00
# 2         0     3.0     0.0       3.76
# 3         0     3.0     0.0       0.00
# 4         0     6.0     0.0       0.00
#
# [5 rows x 50 columns]

# %%
#获取相关系数矩阵
par = data1.corr().iloc[:,[0]].apply(abs).sort_values('语音通话整体满意度',ascending=0)

#各属性相关性的热力图
sns.heatmap(data1.corr(),linewidths=0.1,vmax=1.0, square=True,linecolor='white', annot=True)
# Out:
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 35821 (\N{CJK UNIFIED IDEOGRAPH-8BED}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 38899 (\N{CJK UNIFIED IDEOGRAPH-97F3}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 25972 (\N{CJK UNIFIED IDEOGRAPH-6574}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 28385 (\N{CJK UNIFIED IDEOGRAPH-6EE1}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 24847 (\N{CJK UNIFIED IDEOGRAPH-610F}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 28165 (\N{CJK UNIFIED IDEOGRAPH-6E05}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26224 (\N{CJK UNIFIED IDEOGRAPH-6670}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21542 (\N{CJK UNIFIED IDEOGRAPH-5426}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 36935 (\N{CJK UNIFIED IDEOGRAPH-9047}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21040 (\N{CJK UNIFIED IDEOGRAPH-5230}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 36807 (\N{CJK UNIFIED IDEOGRAPH-8FC7}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 32593 (\N{CJK UNIFIED IDEOGRAPH-7F51}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 32476 (\N{CJK UNIFIED IDEOGRAPH-7EDC}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 38382 (\N{CJK UNIFIED IDEOGRAPH-95EE}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 39064 (\N{CJK UNIFIED IDEOGRAPH-9898}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21150 (\N{CJK UNIFIED IDEOGRAPH-529E}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 23460 (\N{CJK UNIFIED IDEOGRAPH-5BA4}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21830 (\N{CJK UNIFIED IDEOGRAPH-5546}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 19994 (\N{CJK UNIFIED IDEOGRAPH-4E1A}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 34903 (\N{CJK UNIFIED IDEOGRAPH-8857}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20892 (\N{CJK UNIFIED IDEOGRAPH-519C}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26449 (\N{CJK UNIFIED IDEOGRAPH-6751}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20854 (\N{CJK UNIFIED IDEOGRAPH-5176}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20182 (\N{CJK UNIFIED IDEOGRAPH-4ED6}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 65292 (\N{FULLWIDTH COMMA}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 35831 (\N{CJK UNIFIED IDEOGRAPH-8BF7}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 27880 (\N{CJK UNIFIED IDEOGRAPH-6CE8}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26126 (\N{CJK UNIFIED IDEOGRAPH-660E}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21495 (\N{CJK UNIFIED IDEOGRAPH-53F7}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26080 (\N{CJK UNIFIED IDEOGRAPH-65E0}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 25320 (\N{CJK UNIFIED IDEOGRAPH-62E8}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26434 (\N{CJK UNIFIED IDEOGRAPH-6742}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 21548 (\N{CJK UNIFIED IDEOGRAPH-542C}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26029 (\N{CJK UNIFIED IDEOGRAPH-65AD}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 32493 (\N{CJK UNIFIED IDEOGRAPH-7EED}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 35265 (\N{CJK UNIFIED IDEOGRAPH-89C1}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 33073 (\N{CJK UNIFIED IDEOGRAPH-8131}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.draw()
# d:\Anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 